# %%
import requests
from bs4 import BeautifulSoup
url = 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8040239'
response = requests.get(url)
# print(response) # <Response [200]>
# print(response.text)

soup = BeautifulSoup(response.text, 'html.parser')
# print(soup)

# 헤드라인 뉴스 제목 크롤링
title = soup.find('h4', attrs={'class' : 'headline-title'})
# headline = soup.select('headline-title')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <!-- 변수 선언 start -->
# <!--  for global var  -->
# <script type="text/javascript">
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8040239'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

# 헤드라인 뉴스 제목 크롤링
title = soup.find('h4', attrs={'class' : 'headline-title'})
print(title.text)

# 기사 본문의 내용 크롤링
# body = soup.find('div', class_= "detail-body.font-size")
body = soup.select_one('div.detail-body')
# select_one은 요소의 중간에 공백이 있으면 안됨
print(body.text.strip())
# Out:
# 백중사리에 인천 소래포구 침수 우려…“내일 새벽 최고 수위”
# 밀물 수위가 가장 높아지는 ‘백중사리 대조기’를 맞아 인천 저지대 해안가에서 침수 피해 우려가 나오고 있습니다. 국립해양조사원은 올 한 해 밀물 수위가 가장 높아지는 백중사리 대조기 기간이 어제(20일)부터 23일까지 나흘간 이어질 거라고 밝혔습니다. 백중사리 대조기는 백중인 음력 7월 15일을 사나흘 전후해 밀물과 썰물에 따른 바닷물 높이가 가장 크게 벌어지는 기간입니다  오늘(21일) 오전 5시 51분쯤 인천의 조위는 960cm로 경계 단계까지 높아졌습니다. 이후 점차 조위가 낮아졌지만, 오늘 오후 6시 8분쯤에는 관심 단계인 900cm로, 내일(22일) 오전 6시 29분쯤에는 최고수위인 967cm까지 다시 상승할 거로 관측됩니다. 해양수산부는 저지대 해안가인 인천시 남동구 소래포구와 중구 인천수협 일대에서 침수 피해가 발생할 수 있다고 보고 주의를 당부했습니다. 인천 남동구 관계자는 “침수 피해 우려가 있어 내일 새벽에는 소래포구 해안가 주변에 접근하지 못하도록 통제 조치할 예정”이라고 말했습니다.[사진 출처 : 연합뉴스]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium import * 

drive = webdriver.Chrome(r'C:\Program Files\Google\Chrome\Application\chrome.exe')
# 2. 웹페이지 열기
driver.get('https://www.museum.go.kr/site/main/home')

# 3. 특정 요소 찾기
title = driver.find_element(By.TAG_NAME, 'title').text
print(title)

# 4. 브라우저 종료
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 5
#       2 from selenium.webdriver.common.by import By
#       3 from selenium import *
# ----> 5 drive = webdriver.Chrome(r'C:\Program Files\Google\Chrome\Application\chrome.exe')
#       6 # 2. 웹페이지 열기
#       7 driver.get('https://www.museum.go.kr/site/main/home')
#
# File c:\Users\vvv\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# ...
