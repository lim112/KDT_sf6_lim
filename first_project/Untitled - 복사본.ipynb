yangcheon = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
yeongdeungpo = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
yongsan = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
eunpyeong = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
jongno = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
jung = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
jungnang = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
cultures = ["문화회관", "도서관", "박물관","기타" ,"공원장" ,"미술관", "문화원"]

print(gangdong[1]['도서관'])
# Out:
# 0
# 0

# %%
gangnam_1 = 0
# print(gangnam[0]["문화회관"])
gangdong_1 = 0
gangbuk_1 =0
gangseo_1 = 0
gwanak_1 =0
guro_1 = 0
gwangjin_1 = 0
geumcheon_1 =0
nowon_1 = 0
dobong_1 = 0
dongdaemun_1 = 0
dongjak_1 = 0
mapo_1 = 0
seodaemun_1 = 0
seocho_1 =0
seongdong_1 = 0
seongbuk_1 = 0
songpa_1 =0
yangcheon_1 =0
yeongdeungpo_1 = 0
yongsan_1 = 0
eunpyeong_1 = 0
jongno_1 = 0
jung_1 = 0
jungnang_1 = 0

# %%
import pandas as pd
df = pd.read_csv('seoul_culture_place.csv',encoding='cp949')
subject_title_list = df.iloc[0:1075, 1]
print(subject_title_list)
# Out:
# 0            기타
# 1            기타
# 2           공연장
# 3           도서관
# 4        문화예술회관
#          ...
# 1069         기타
# 1070        도서관
# 1071         기타
# 1072    박물관/기념관
# 1073         기타
# Name: 주제분류, Length: 1074, dtype: object

# %%
print(subject_title_list)
# Out:
# 0            기타
# 1            기타
# 2           공연장
# 3           도서관
# 4        문화예술회관
#          ...
# 1069         기타
# 1070        도서관
# 1071         기타
# 1072    박물관/기념관
# 1073         기타
# Name: 주제분류, Length: 1074, dtype: object

# %%
# with open('datas/seoul_culture_place.csv','r')as f:
#     data = csv.reader(f)        
cultures = ["문화회관", "도서관", "박물관","기타" ,"공원장" ,"미술관", "문화원"]
gangnam = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
count = 0
count_g = 0
for pg in place_gu:
    if ('강남' in pg ) and ('미술관' in subject_title_list):
        count_g = count_g + 1
            # if cultures[1] in :
                # gangnam[0]['문화회관'] = gangnam[0]['문화회관'] + 1
                # count = count + 1
print(gangnam[0]['문화회관'])
print(count)
print(count_g)
print(cultures[1])
# Out:
# 0
# 0
# 0
# 도서관

# %%
# 필요한 주제 분류와 주소
subjects = ["문화회관", "도서관", "박물관", "기타", "공원장", "미술관", "문화원"]
addresses = ['강남','강동','강북','강서','관악','광진','구로','금천','노원','도봉',
             '동대문','동작','마포','서대문','서초','성동','송파','양천','영등포',
             '용산','은평','종로','중랑구']

# 필터링
filtered_df = df[df['주제분류'].isin(subjects) & df['문화시설주소'].str.contains('|'.join(addresses))]

# %%
addresses = ['강남', '강동', '강북', '강서', '관악', '광진', '구로', '금천', '노원', '도봉',
             '동대문', '동작', '마포', '서대문', '서초', '성동', '송파', '양천', '영등포',
             '용산', '은평', '종로', '중랑구']

# 주소들을 정규표현식 패턴으로 변환
address_pattern = '|'.join(addresses)
print(address_pattern)
# Out:
# 강남|강동|강북|강서|관악|광진|구로|금천|노원|도봉|동대문|동작|마포|서대문|서초|성동|송파|양천|영등포|용산|은평|종로|중랑구

# %%
for i in gu_list:
#     # CSV 파일 읽기
    print(f'df_{i} = pd.read_excel('f'filtered_data_{i}.xlsx')
# Out:
# df_강남 = pd.read_excel(filtered_data_강남.xlsx
# df_강동 = pd.read_excel(filtered_data_강동.xlsx
# df_강북 = pd.read_excel(filtered_data_강북.xlsx
# df_강서 = pd.read_excel(filtered_data_강서.xlsx
# df_관악 = pd.read_excel(filtered_data_관악.xlsx
# df_광진 = pd.read_excel(filtered_data_광진.xlsx
# df_구로 = pd.read_excel(filtered_data_구로.xlsx
# df_금천 = pd.read_excel(filtered_data_금천.xlsx
# df_노원 = pd.read_excel(filtered_data_노원.xlsx
# df_도봉 = pd.read_excel(filtered_data_도봉.xlsx
# df_동대문 = pd.read_excel(filtered_data_동대문.xlsx
# df_동작 = pd.read_excel(filtered_data_동작.xlsx
# df_마포 = pd.read_excel(filtered_data_마포.xlsx
# df_서대문 = pd.read_excel(filtered_data_서대문.xlsx
# df_서초 = pd.read_excel(filtered_data_서초.xlsx
# df_성동 = pd.read_excel(filtered_data_성동.xlsx
# df_송파 = pd.read_excel(filtered_data_송파.xlsx
# df_양천 = pd.read_excel(filtered_data_양천.xlsx
# df_영등포 = pd.read_excel(filtered_data_영등포.xlsx
# df_용산 = pd.read_excel(filtered_data_용산.xlsx
# df_은평 = pd.read_excel(filtered_data_은평.xlsx
# df_종로 = pd.read_excel(filtered_data_종로.xlsx
# df_중랑구 = pd.read_excel(filtered_data_중랑구.xlsx

# %%
import pandas as pd

# 구 리스트 정의
gu_list = ['강남', '강동', '강북', '강서', '관악', '광진', '구로', '금천', '노원', '도봉', '동대문', '동작', '마포', '서대문', '서초', '성동', '송파', '양천', '영등포', '용산', '은평', '종로', '중랑구']
df_강남 = pd.read_excel(f'filtered_data_강남.xlsx')
df_강동 = pd.read_excel(f'filtered_data_강동.xlsx')
df_강북 = pd.read_excel(f'filtered_data_강북.xlsx')
df_강서 = pd.read_excel(f'filtered_data_강서.xlsx')
df_관악 = pd.read_excel(f'filtered_data_관악.xlsx')
df_광진 = pd.read_excel(f'filtered_data_광진.xlsx')
df_구로 = pd.read_excel(f'filtered_data_구로.xlsx')
df_금천 = pd.read_excel(f'filtered_data_금천.xlsx')
df_노원 = pd.read_excel(f'filtered_data_노원.xlsx')
df_도봉 = pd.read_excel(f'filtered_data_도봉.xlsx')
df_동대문 = pd.read_excel(f'filtered_data_동대문.xlsx')
df_동작 = pd.read_excel(f'filtered_data_동작.xlsx')
df_마포 = pd.read_excel(f'filtered_data_마포.xlsx')
df_서대문 = pd.read_excel(f'filtered_data_서대문.xlsx')
df_서초 = pd.read_excel(f'filtered_data_서초.xlsx')
df_성동 = pd.read_excel(f'filtered_data_성동.xlsx')
df_송파 = pd.read_excel(f'filtered_data_송파.xlsx')
df_양천 = pd.read_excel(f'filtered_data_양천.xlsx')
df_영등포 = pd.read_excel(f'filtered_data_영등포.xlsx')
df_용산 = pd.read_excel(f'filtered_data_용산.xlsx')
df_은평 = pd.read_excel(f'filtered_data_은평.xlsx')
df_종로 = pd.read_excel(f'filtered_data_종로.xlsx')
df_중랑구 = pd.read_excel(f'filtered_data_중랑구.xlsx')

for j in subjects:
    if 
    
# 결과 확인 (마지막 구에 해당하는 데이터 출력)
print(filtered_df)
# Out:
#       번호 주제분류        문화시설명                             문화시설주소         위도  \
# 0    175   기타     중랑구평생학습관                서울특별시 중랑구 망우로67길 10  37.600597
# 1    156  공연장      중랑문화체육관               서울특별시 중랑구 사가정로72길 47  37.579300
# 2    157  도서관    중랑구립정보도서관               서울특별시 중랑구 신내로15길 197  37.615171
# 3    172   기타     중랑구민체육센터               서울특별시 중랑구 신내로15길 189  37.615182
# 4    231   기타       중랑구민회관                  서울특별시 중랑구 면목로 238  37.574088
# 5    390   기타   옹기테마공원 체험장               서울특별시 중랑구 신내로21길 116  37.612654
# 6    565  미술관       중랑아트센터      서울특별시 중랑구 망우로 353 이노시티 C동 B2F  37.598211
# 7    656   기타       중랑장미공원                      서울 중랑구 묵동 375  37.615529
# 8    738  문화원        중랑문화원  서울특별시 중랑구 면목로 238(면목동, 중랑구민회관 3층)  37.573954
# 9    843  도서관  중랑구립면목정보도서관           서울 중랑구 면목로 397 면목본동 주민센터  37.587356
# 10   856   기타       용마폭포공원              서울특별시 중랑구 용마산로 250-12  37.573352
# 11   931   기타         중랑구청               서울 중랑구 봉화산로 179 중랑구청  37.606564
# 12  1071  도서관      중랑상봉도서관               서울특별시 중랑구 동일로114길 10  37.592892
# 13  1072   기타        중랑캠핑숲                  서울특별시 중랑구 송림길 172  37.606861
#
#             경도                전화번호          팩스번호  \
# 0   127.101584        02-2094-1886           NaN
# 1   127.095771         02-436-9200           NaN
# 2   127.086906        02-3407-1111  02-3422-1114
# 3   127.087482      02-3423-1070~4           NaN
# 4   127.085129        02-2207-6130  02-2207-6133
# 5   127.088519  02-3407-6546, 6547           NaN
# 6   127.091519        02-3407-6541           NaN
# 7   127.073271                  없음           NaN
# 8   127.085105       02-492-0066~7  02-2207-5761
# 9   127.087555            24324123           NaN
# 10  127.089122        02-2094-2965           NaN
# 11  127.092725        02-2094-0114   02-490-4658
# 12  127.080852        02-2209-0090           NaN
# 13  127.110697      0507-1348-8138           NaN
#
#                                                  홈페이지           관람시간  ...  \
# 0            https://www.jungnang.go.kr/study/main.do            NaN  ...
# 1         https://www.jungnangimc.or.kr/html/01020100            NaN  ...
# 2             https://www.jungnanglib.seoul.kr/jnlib/            NaN  ...
# 3         https://www.jungnangimc.or.kr/html/01010100            NaN  ...
# 4                               www.jungnangimc.or.kr  09:00 ~ 21:00  ...
# 5   http://www.jungnang.go.kr/portal/main/contents...            NaN  ...
# 6                   https://www.jnac.or.kr/index.html            NaN  ...
# 7   https://seoulrose.jnfac.or.kr/festival/place.html            NaN  ...
# 8                                https://www.ejnc.kr/            NaN  ...
# 9    https://www.jungnanglib.seoul.kr/mmlib/index.php            NaN  ...
# 10  https://www.jungnang.go.kr/portal/main/content...            NaN  ...
# 11          https://www.jungnang.go.kr/portal/main.do            NaN  ...
# 12   https://www.jungnanglib.seoul.kr/sblib/index.php            NaN  ...
# 13                      http://www.joongrangsoop.com/            NaN  ...
#
#    기타사항                                               시설소개 무료구분  지하철 버스정거장  \
# 0   NaN  <p>중랑구평생학습관</p><p><br></p><p>시설안내</p><p>3층 안내데...   무료  NaN   NaN
# 1   NaN  <p> </p><table border='0' cellspacing='0' cell...   유료  NaN   NaN
# 2   NaN  <div style='text-align: center;' align='center...   무료  NaN   NaN
# 3   NaN  <table border='0' cellspacing='0' cellpadding=...   무료  NaN   NaN
# 4   NaN  <p>지하철 7호선이 지나는 용마산역 1번 출구 인근에 위치한 중랑구민회관은 모든 ...   유료  NaN   NaN
# 5   NaN  <h2 class='top10' style='font-family:; box-siz...   무료  NaN   NaN
# 6   NaN  <p style='line-height: 1.8;'><span style='font...   무료  NaN   NaN
# 7   NaN  <p class='0' style='border: 0px; box-sizing: i...   무료  NaN   NaN
# 8   NaN  <div style='text-align: left;' align='left'><s...   무료  NaN   NaN
# 9   NaN  <div style='text-align: center;' align='center...   무료  NaN   NaN
# 10  NaN  <span style='font-size: 12pt;'>면목동 산 1-4번지에 위치...   무료  NaN   NaN
# 11  NaN  <div style='text-align: center;' align='center...   무료  NaN   NaN
# 12  NaN  <div style='text-align: center;' align='center...   무료  NaN   NaN
# 13  NaN  <span style='font-size: 12pt;'>중랑 캠핑장을 찾아주신 여러...   유료  NaN   NaN
#
#     YELLOW GREEN BLUE  RED  공항버스
# 0      NaN   NaN  NaN  NaN   NaN
# 1      NaN   NaN  NaN  NaN   NaN
# 2      NaN   NaN  NaN  NaN   NaN
# 3      NaN   NaN  NaN  NaN   NaN
# 4      NaN   NaN  NaN  NaN   NaN
# 5      NaN   NaN  NaN  NaN   NaN
# 6      NaN   NaN  NaN  NaN   NaN
# 7      NaN   NaN  NaN  NaN   NaN
# 8      NaN   NaN  NaN  NaN   NaN
# 9      NaN   NaN  NaN  NaN   NaN
# 10     NaN   NaN  NaN  NaN   NaN
# 11     NaN   NaN  NaN  NaN   NaN
# 12     NaN   NaN  NaN  NaN   NaN
# 13     NaN   NaN  NaN  NaN   NaN
#
# [14 rows x 25 columns]

# %%
import pandas as pd
gu_list = ['강남','강동','강북','강서','관악','광진','구로','금천','노원','도봉','동대문','동작','마포','서대문','서초','성동','송파','양천','영등포','용산','은평','종로','중랑구']

for i in gu_list:
# CSV 파일 읽기
        df = pd.read_csv(f'seoul_culture_place.csv', encoding='cp949')
        # NaN 값 제거
        df = df.dropna(subset=['문화시설주소'])
        # 조건에 맞는 행들 필터링
        filtered_df = df[df['문화시설주소'].str.contains(i)]
        # 추출된 행들 저장하기 (예: 'filtered_data.csv' 파일로 저장)
        filtered_df.to_excel(f'filtered_data_{i}.xlsx', index=False, encoding='utf-8')

# 결과 확인
print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 12
#      10         filtered_df = df[df['문화시설주소'].str.contains(i)]
#      11         # 추출된 행들 저장하기 (예: 'filtered_data.csv' 파일로 저장)
# ---> 12         filtered_df.to_excel(f'filtered_data_{i}.xlsx', index=False, encoding='utf-8')
#      14 # 결과 확인
#      15 print(filtered_df)
#
# File c:\Users\vvv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_excel() got an unexpected keyword argument 'encoding'

# %%
gu_list = ['강남','강동','강북','강서','관악','광진','구로','금천','노원','도봉','동대문','동작','마포','서대문','서초','성동','송파','양천','영등포','용산','은평','종로','중랑구']
# subject_list = subject_set
gu_eng_list = ['gangnam','gangdong','gangbuk','gangseo','gwanak','guro','gwangjin','geumcheon',
'nowon','dobong','dongdaemun','dongjak','mapo','seodaemun','seocho','seongdong','seongbuk',
'songpa','yangcheon','yeongdeungpo','yongsan','eunpyeong','jongno','jung','jungnang']

# %%
# 리더님
import folium
# Map() 클래스 사용, location-[위도, 경도], zoom_start-확대/축소
seoul_map = folium.Map(location=[37.539705, 126.94604], zoom_start=12)
# locations = [
#     [37.539705, 126.94604],  #마포역
#     [37.497952, 127.027619], #강남역
#     [37.57173, 127.011069]   #동대문역
# ]
# 리스트와 딕셔너리
map_info = [
    {"location": [37.539705, 126.94604], "popup": "마포역"},
    {"location": [37.497952, 127.027619], "popup": "강남역"},
    {"location": [37.57173, 127.011069], "popup": "동대문역"},
]
for map in map_info:
    folium.Marker(
        location=map["location"],
        popup=map["popup"],
        icon = folium.Icon(icon='arrow-down', color='blue')
    ).add_to(seoul_map)
seoul_map

# %%
print(place_gu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(place_gu)
#
# NameError: name 'place_gu' is not defined

# %%
print(subject_set)
# Out:
# {'기타', '도서관', '문화원', '박물관/기념관', '공연장', '미술관', '문화예술회관'}

# %%
import csv
count = 0
count_gu = 0

place = []
with open('datas/seoul_culture_place.csv','r')as f:
    data = csv.reader(f)
    header = next(data)
    place_gu = []
    # subject = {'기타','공연장','도서관'}
    subject_list = []
    subject_set = set()
    for row in data:         
        subject_set.add(row[1])
        place_gu.append(row[3])
        if row[1] == '기타':
           place.append(row[2]) 
           count += 1
        for i in subject_list:   
            if '강남' in row[3] :
                gangnam_1 += 1
            if '강동' in row[3] :
                gangdong_1 += 1
            elif '강북' in row[3] :
                gangbuk_1 += 1
            elif '강서' in row[3] :
                gangseo_1 += 1
            elif '관악' in row[3] :
                gwanak_1 += 1
            elif '광진' in row[3] :
                gwangjin_1 += 1
            elif '구로' in row[3] :
                guro_1 += 1
            elif '금천' in row[3] :
                geumcheon_1 += 1
            elif '노원' in row[3] :
                nowon_1 += 1
            elif '도봉' in row[3] :
                dobong_1 += 1
            elif '동대문' in row[3] :
                dongdaemun_1 += 1
            elif '동작' in row[3] :
                dongjak_1 += 1
            elif '마포' in row[3] :
                mapo_1 += 1
            elif '서대문' in row[3] :
                seodaemun_1 += 1
            elif '서초' in row[3] :
                seocho_1 += 1
            elif '성동' in row[3] :
                seongdong_1 += 1
            elif '성북' in row[3] :
                seongbuk_1 += 1
            elif '송파' in row[3] :
                songpa_1 += 1
            elif '양천' in row[3] :
                yangcheon_1 += 1
            elif '영등포' in row[3] :
                yeongdeungpo_1 += 1
            elif '용산' in row[3] :
                yongsan_1 += 1
            elif '은평' in row[3] :
                eunpyeong_1 += 1
            elif '종로' in row[3] :
                jongno_1 += 1
            elif '중구' in row[3] :
                jung_1 += 1
            elif '중랑' in row[3] :
                jungnang_1 += 1
# print(dobong)        
# print(nowon)
# print(gangnam)
# print(gangdong)
# print(gangbuk)
# print(gangseo)
# print(gwanak)
# print(gwangjin)
# print(guro)
# print(geumcheon)
# print(nowon)
# print(dobong)
# print(dongdaemun)
# print(dongjak)
# print(mapo)
# print(seodaemun)
# print(seocho)
# print(seongdong)
# print(seongbuk)
# print(songpa)
# print(yangcheon)
# print(yeongdeungpo)
# print(yongsan)
# print(eunpyeong)
# print(jongno)
# print(jung)
# print(jungnang)
# # print(count_gu)
# print(place_gu)
# print(place)
# print(f'문화공간 셋 : {subject_set}')
# subject_list = subject_set
# print(f'문화공간 리스트 : {subject_list}')
# print(place[1])

# %%
for i in place:
    print(i)
# Out:
# 경희대학교
# DDP(동대문디자인플라자)
# 금천예술공장
# 양천구민체육센터
# 광진교 8번가
# 강북구청
# 구로구청
# 노들섬 복합문화공간
# 한성대학교
# 동대문구민체육센터
# 양천구청
# 노원구청
# 예지원
# 롯데월드 아이스링크
# 온조대왕문화체육관
# 용산구문화체육센터
# 올림픽기념국민생활관
# 육군사관학교
# 동대문구청
# 서울문화재단
# 시민청
# 동작구청
# 강남문화재단
# 서울풍물시장 전통문화체험관
# 강남스포츠문화센터
# 대진체육관
# 송파구청
# 서울문화예술교육센터 양천
# 중랑구평생학습관
# 국립국어원 우리말 꿈터
# 남산골한옥마을
# 구로구민체육센터
# 강남구민체육관
# 금천구청
# 누하동 259
# 해공체육문화센터
# 아트잠실
# 금천 청년꿈터
# 흥인지문
# 난지한강공원
# 서울시민대학 중부권 캠퍼스
# 명동아트브리즈
# 서울시농수산식품공사 가락몰 쿠킹스튜디오
# 잠원 한강공원
# 불광천미디어센터
# 흑석체육센터
# 국가무형유산전수교육관
# 서울로봇인공지능과학관
# 양재 aT센터
# 공유공간 자기만의방
# 성북구민회관
# 앤스 갤러리 카페(Ns Cafe)
# 오목공원
# 숭실대학교 한경직기념관
# 잠실한강공원
# 성신여자대학교 운정그린캠퍼스 대강당
# 미디어 아트 갤러리 언더독뮤지엄
# 북촌도시재생지원센터 가회동 공공한옥
# 노원구민의전당
# 강남전시실
# 경복궁 수정전
# 서울숲 가족마당
# 종묘
# 대우재단빌딩 ORBIS
# 마루공원
# 마포여성동행센터
# 의정부지 역사유적광장
# 서울시립청소년미디어센터
# LES601 선유
# 상촌재
# 청춘삘딩
# 신영시장
# N서울타워
# 여의도공원
# 1인미디어콤플렉스
# 이화여자대학교 대강당
# 서울생활문화센터 신도림
# 서울시립대학교 음악관
# 용마폭포공원
# 광화문라운지
# 서울특별시농업기술센터
# 마을극장 흰고무신
# 성수 산업혁신공간
# 카페 쓸
# 총신대학교 백남조 기념홀
# 상상비즈아카데미
# 눈스퀘어
# 엑셈
# 뚝섬한강공원
# 서울시민대학 동남권캠퍼스
# 표현하다 스튜디오
# 서울로미디어캔버스
# 미인도
# 강동성심병원
# 여의도 한강공원
# 서울시 관악복합평생교육센터
# 서울시민대학 모두의학교 캠퍼스
# 중랑구청
# KT&G 상상플래닛
# 낙성대공원
# 탑골공원
# 삼청공원
# 삼태기숲
# 보신각
# 은평한옥마을어울림터
# 오소리 아트홀
# 한강공원
# 낙산공원
# G밸리창업복지센터
# 열린송현녹지광장
# 국립서울현충원
# 포스코타워 역삼
# 카페프로젝트이응
# 반포한강공원
# 삼성해맞이공원
# 창신소통공작소
# 푸른수목원
# 콘래드 서울 호텔
# 에즈에스아카데미
# 선농단역사문화관
# 서울디자인창업센터
# 원당샘공원
# 올림픽공원
# 복합문화공간 홍대스페이스M
# 솔밭근린공원
# 종로여성인력개발센터
# 대한성공회 서울주교좌성당
# 청계광장
# 서서울호수공원
# 용산어린이정원
# 서리풀청년아트센터
# 갤러리자유(Gallery Jayu)
# 남산XR스튜디오
# 목동종합운동장실내아이스링크
# 스페이스살림
# 소담상회 with 아이디어스 크래프트랩
# 더레퍼런스
# 문화비축기지
# 서울식물원
# 코엑스 별마당 도서관
# 반포대로
# 공릉청소년문화정보센터
# 백석비전센터
# 월드컵공원
# 서초구청
# 중랑캠핑숲
# 정동제일교회

# %%
def is_place_box_click():
    try:
        place_box_click = driver.find_element(By.CLASS_NAME, 'hfpxzc').click()
        time.sleep(2)
    except:
        try
            place_box_click = driver.find_element(By.xpath, '/html/body/div[1]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[1]/div/a').click()
            time.sleep(2)
        except:
            pass
def is_place_box_info(): 
    try:
        place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text
        time.sleep(1)
    except:
        try:
            place_box_name = driver.find_element(By.xpath, '/html/body/div[1]/div[3]/div[8]/div[9]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span[1]/span/button').text
            time.sleep(1)
        except:
            try:
                place_box_name = driver.find_element(By.CLASS_NAME, 'DUwDvf.lfPIob').text
                time.sleep(1)
            except:
                pass
# Out:
#   Cell In[5], line 6
#     try
#        ^
# SyntaxError: expected ':'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
value = []
# 크롬 드라이버 실행
driver = webdriver.Chrome()
count = 0
for i in range(3,278):
    # Google Maps 페이지 열기
    driver.get('https://www.google.com/maps/?authuser=0&entry=ttu&g_ep=EgoyMDI0MDgyMS4wIKXMDSoASAFQAw%3D%3D')
    
    # 페이지 로딩 대기
    time.sleep(3)
    
    # 검색창 요소 찾기
    search_box = driver.find_element(By.CLASS_NAME, 'searchboxinput')
    time.sleep(3)
    # 검색어 입력
    search_box.click()  # 검색창 클릭 (선택 사항)
    search_box.send_keys(place[i])
    # 검색 실행 (엔터 키 입력)
    search_box.send_keys(u'\ue007')  # 엔터 키를 의미하는 유니코드
    is_place_box_click
    is_place_box_info    
    time.sleep(3)
    #place_box_info = driver.find_element(By.xpath,'//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span[1]/span/button')
    print(place_box_info)
    if place[i] == place_box_name:
        value.append(place_box_info)
    else:
        print(f'검색한 데이터가 {place[i]}가 아닙니다')
    time.sleep(3)
    count = count + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 23
#      21 # 검색 실행 (엔터 키 입력)
#      22 search_box.send_keys(u'\ue007')  # 엔터 키를 의미하는 유니코드
# ---> 23 is_place_box_click
#      24 is_place_box_info
#      25 time.sleep(3)
#
# NameError: name 'is_place_box_click' is not defined

# %%
driver = webdriver.Chrome()
for i in range(278):
# Google Maps 페이지 열기
    driver.get('https://www.google.com/maps/?authuser=0&entry=ttu&g_ep=EgoyMDI0MDgyMS4wIKXMDSoASAFQAw%3D%3D')
    
    # 페이지 로딩 대기
    time.sleep(2)
    # 검색창 요소 찾기
    search_box = driver.find_element(By.CLASS_NAME, 'searchboxinput')
    time.sleep(1)
    # 검색어 입력
    
    search_box.click()  # 검색창 클릭 (선택 사항)
    search_box.send_keys(place[i])
    
    # 검색 실행 (엔터 키 입력)
    search_box.send_keys(u'\ue007')  # 엔터 키를 의미하는 유니코드
    time.sleep(1)
    
    try:
        place_box_click = driver.find_element(By.CLASS_NAME, 'hfpxzc').click()
    except:
        print('에러발생')
    finally:
        time.sleep(1)
    
    place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text

    print(place_box_info)
    value.append(place_box_info)
    time.sleep(1)
    count = count + 1
# Out:
# 사립대학교
# 카페
# 에러발생
# 아트 센터
# 에러발생
# 체육관
# 에러발생
# 문화적 랜드마크
# 숙박 업소
# 학교
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[200], line 27
#      24 finally:
#      25     time.sleep(1)
# ---> 27 place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text
#      29 print(place_box_info)
#      30 value.append(place_box_info)
#
# File C:\ana\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ana\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File C:\ana\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".DkEaL"}
#   (Session info: chrome=128.0.6613.84); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF63CF4B632+29090]
# 	(No symbol) [0x00007FF63CEBE6E9]
# 	(No symbol) [0x00007FF63CD7B1CA]
# 	(No symbol) [0x00007FF63CDCEFD7]
# 	(No symbol) [0x00007FF63CDCF22C]
# 	(No symbol) [0x00007FF63CE197F7]
# 	(No symbol) [0x00007FF63CDF672F]
# 	(No symbol) [0x00007FF63CE165D9]
# 	(No symbol) [0x00007FF63CDF6493]
# 	(No symbol) [0x00007FF63CDC09B1]
# 	(No symbol) [0x00007FF63CDC1B11]
# 	GetHandleVerifier [0x00007FF63D26881D+3294093]
# 	GetHandleVerifier [0x00007FF63D2B4403+3604339]
# 	GetHandleVerifier [0x00007FF63D2AA2C7+3563063]
# 	GetHandleVerifier [0x00007FF63D006F16+797318]
# 	(No symbol) [0x00007FF63CEC986F]
# 	(No symbol) [0x00007FF63CEC5454]
# 	(No symbol) [0x00007FF63CEC55E0]
# 	(No symbol) [0x00007FF63CEB4A7F]
# 	BaseThreadInitThunk [0x00007FFAD1477374+20]
# 	RtlUserThreadStart [0x00007FFAD29DCC91+33]

# %%
# place_dic = dictionar
place_tuple = tuple(place)
# print(len(place))
# print(len(place_tuple))

# 딕셔너리 초기화
place_dic = {}

# 딕셔너리에 값 추가
for i in place:
    place_dic[i] = i

# 결과 출력
print(place_dic)
# Out:
# {'경희대학교': '경희대학교', 'DDP(동대문디자인플라자)': 'DDP(동대문디자인플라자)', '금천예술공장': '금천예술공장', '양천구민체육센터': '양천구민체육센터', '광진교 8번가': '광진교 8번가', '강북구청': '강북구청', '구로구청': '구로구청', '노들섬 복합문화공간': '노들섬 복합문화공간', '한성대학교': '한성대학교', '동대문구민체육센터': '동대문구민체육센터', '양천구청': '양천구청', '노원구청': '노원구청', '예지원': '예지원', '롯데월드 아이스링크': '롯데월드 아이스링크', '온조대왕문화체육관': '온조대왕문화체육관', '용산구문화체육센터': '용산구문화체육센터', '올림픽기념국민생활관': '올림픽기념국민생활관', '육군사관학교': '육군사관학교', '동대문구청': '동대문구청', '서울문화재단': '서울문화재단', '시민청': '시민청', '동작구청': '동작구청', '강남문화재단': '강남문화재단', '서울풍물시장 전통문화체험관': '서울풍물시장 전통문화체험관', '강남스포츠문화센터': '강남스포츠문화센터', '대진체육관':