# %%
# import pandas as pd
# culture = pd.read_excel('./culture_money.xlsx')

# title = ['전시회 관람','박물관 관람','음악 및 무용발표회 관람',
#          '전통예술공연 관람','연극공연 관람','영화관람','대중공연 관람'
#          ,'운동경기 관람','문학행사 관람']
# title = 
# print(culture)

# %%
강남 = [
    {'gangnam_문화회관' : 0},
{'gangnam_도서관' : 0},
{'gangnam_박물관' : 0},
{'gangnam_기타' :0},
{'gangnam_공원장':0},
{'gangnam_미술관':0},
{'gangnam_문화원' : 0}
]
# print(강남)

# if 'gangnam' == 강남:
#     print('일치')

# %%
gangnam = [{"gangnam_문화회관" : 0}, {"gangnam_도서관" : 0}, {"gangnam_박물관" : 0}, {"gangnam_기타" : 0}, {"gangnam_공원장" : 0}, {"gangnam_미술관" : 0}, {"gangnam_문화원" : 0}]
print(gangnam[0]["gangnam_문화회관"])
gangdong = [{"gangdong_문화회관" : 0}, {"gangdong_도서관" : 0}, {"gangdong_박물관" : 0}, {"gangdong_기타" : 0}, {"gangdong_공원장" : 0}, {"gangdong_미술관" : 0}, {"gangdong_문화원" : 0}]
gangbuk = [{"gangbuk_문화회관" : 0}, {"gangbuk_도서관" : 0}, {"gangbuk_박물관" : 0}, {"gangbuk_기타" : 0}, {"gangbuk_공원장" : 0}, {"gangbuk_미술관" : 0}, {"gangbuk_문화원" : 0}]
gangseo = [{"gangseo_문화회관" : 0}, {"gangseo_도서관" : 0}, {"gangseo_박물관" : 0}, {"gangseo_기타" : 0}, {"gangseo_공원장" : 0}, {"gangseo_미술관" : 0}, {"gangseo_문화원" : 0}]
gwanak = [{"gwanak_문화회관" : 0}, {"gwanak_도서관" : 0}, {"gwanak_박물관" : 0}, {"gwanak_기타" : 0}, {"gwanak_공원장" : 0}, {"gwanak_미술관" : 0}, {"gwanak_문화원" : 0}]
guro = [{"guro_문화회관" : 0}, {"guro_도서관" : 0}, {"guro_박물관" : 0}, {"guro_기타" : 0}, {"guro_공원장" : 0}, {"guro_미술관" : 0}, {"guro_문화원" : 0}]
gwangjin = [{"gwangjin_문화회관" : 0}, {"gwangjin_도서관" : 0}, {"gwangjin_박물관" : 0}, {"gwangjin_기타" : 0}, {"gwangjin_공원장" : 0}, {"gwangjin_미술관" : 0}, {"gwangjin_문화원" : 0}]
geumcheon = [{"geumcheon_문화회관" : 0}, {"geumcheon_도서관" : 0}, {"geumcheon_박물관" : 0}, {"geumcheon_기타" : 0}, {"geumcheon_공원장" : 0}, {"geumcheon_미술관" : 0}, {"geumcheon_문화원" : 0}]
nowon = [{"nowon_문화회관" : 0}, {"nowon_도서관" : 0}, {"nowon_박물관" : 0}, {"nowon_기타" : 0}, {"nowon_공원장" : 0}, {"nowon_미술관" : 0}, {"nowon_문화원" : 0}]
dobong = [{"dobong_문화회관" : 0}, {"dobong_도서관" : 0}, {"dobong_박물관" : 0}, {"dobong_기타" : 0}, {"dobong_공원장" : 0}, {"dobong_미술관" : 0}, {"dobong_문화원" : 0}]
seongbuk = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
songpa = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
yangcheon = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
yeongdeungpo = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
yongsan = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
eunpyeong = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
jongno = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
jung = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
jungnang = [{"문화회관" : 0}, {"도서관" : 0}, {"박물관" : 0}, {"기타" : 0}, {"공원장" : 0}, {"미술관" : 0}, {"문화원" : 0}]
cultures = ["문화회관", "도서관", "박물관","기타" ,"공원장" ,"미술관", "문화원"]

print(gangdong[1]['도서관'])
# Out:
# 0
# 0

# %%
import pandas as pd
df = pd.read_csv('seoul_culture_place.csv',encoding='cp949')
subject_title_list = df.iloc[0:1075, 1]
print(subject_title_list)
# Out:
# 0            기타
# 1            기타
# 2           공연장
# 3           도서관
# 4        문화예술회관
#          ...
# 1069         기타
# 1070        도서관
# 1071         기타
# 1072    박물관/기념관
# 1073         기타
# Name: 주제분류, Length: 1074, dtype: object

# %%
# with open('datas/seoul_culture_place.csv','r')as f:
#     data = csv.reader(f)        
for pg in place_gu:
    if '강남' in pg:
        for sb in subject_title_list:
            if :
                gangnam[]

# %%
강동 = [
    {'gangdong_문화회관' : 0},
{'gangdong_도서관' : 0},
{'gangdong_박물관' : 0},
{'gangdong_기타' :0},
{'gangdong_공원장': 0},
{'gangdong_미술관':0},
{'gangdong_문화원' : 0}
]
# 강남
print(강동)

for i in gu_eng:
    print(f'[{'{i}_문화회관' : 0},{'{i}_도서관' : 0},{'{i}_박물관' : 0},{'{i}_기타' :0},{'{i}_공원장': 0},{'{i}_미술관':0},{'{i}_문화원' : 0}]')
# 강남
print(강동)
# Out:
# [{'gangdong_문화회관': 0}, {'gangdong_도서관': 0}, {'gangdong_박물관': 0}, {'gangdong_기타': 0}, {'gangdong_공원장': 0}, {'gangdong_미술관': 0}, {'gangdong_문화원': 0}]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 14
#      11 print(강동)
#      13 for i in gu_eng:
# ---> 14     print(f'[{'{i}_문화회관' : 0},{'{i}_도서관' : 0},{'{i}_박물관' : 0},{'{i}_기타' :0},{'{i}_공원장': 0},{'{i}_미술관':0},{'{i}_문화원' : 0}]')
#      15 # 강남
#      16 print(강동)
#
# ValueError: Space not allowed in string format specifier

# %%
gu = ['강남','강동','강북','강서','관악','광진','구로','금천','노원','도봉','동대문','동작','마포','서대문','서초','성동','송파','양천','영등포','용산','은평','종로','중랑구']
subject_list = subject_set
gu_eng = ['gangnam','gangdong','gangbuk','gangseo','gwanak','guro','gwangjin','geumcheon',
'nowon','dobong','dongdaemun','dongjak','mapo','seodaemun','seocho','seongdong','seongbuk',
'songpa','yangcheon','yeongdeungpo','yongsan','eunpyeong','jongno','jung','jungnang']

# %%
# 리더님
import folium
# Map() 클래스 사용, location-[위도, 경도], zoom_start-확대/축소
seoul_map = folium.Map(location=[37.539705, 126.94604], zoom_start=12)
# locations = [
#     [37.539705, 126.94604],  #마포역
#     [37.497952, 127.027619], #강남역
#     [37.57173, 127.011069]   #동대문역
# ]
# 리스트와 딕셔너리
map_info = [
    {"location": [37.539705, 126.94604], "popup": "마포역"},
    {"location": [37.497952, 127.027619], "popup": "강남역"},
    {"location": [37.57173, 127.011069], "popup": "동대문역"},
]
for map in map_info:
    folium.Marker(
        location=map["location"],
        popup=map["popup"],
        icon = folium.Icon(icon='arrow-down', color='blue')
    ).add_to(seoul_map)
seoul_map

# %%
print(place_gu)
# Out:
# ['서울특별시 동대문구 경희대로 26', '서울특별시 중구 을지로 281', '서울특별시 성동구 연무장7길 11', '서울특별시 은평구 진관2로 111-51', '서울특별시 노원구 중계로 181', '서울특별시 종로구 혜화로 35', '서울특별시 금천구 범안로15길 57', '서울특별시 송파구 동남로 263', '서울특별시 동대문구 회기로 56', '서울특별시 용산구 소월로 132', '서울특별시 중구 서소문로11길 19', '서울특별시 구로구 고척로45길 31', '서울특별시 양천구 목동동로 87', '한강로3가 64-1 , 용산센트럴파크 해링턴스퀘어 공공시설동 1,2층', '서울 강동구 천호동 527-2', '서울특별시 종로구 동숭길 3', '서울특별시 노원구 동일로174길 27', '서울특별시 종로구 우정국로 26', '서울특별시 종로구 창의문로10길 11', '서울특별시 양천구 목동서로 367', '서울 종로구 세종대로 175', '서울특별시 도봉구 삼양로 556', '서울특별시 강북구 도봉로89길 13', '서울특별시 구로구 가마산로 245', '서울특별시 용산구 양녕로 445', '서울특별시 영등포구 문래로20길 49', '서울특별시 구로구 구로동로26길 54', '서울특별시 양천구 목동동로 81', '서울특별시 양천구 목동동로 233', '서울특별시 용산구 이태원로55길 60-16', '서울특별시 서초구 사평대로 55', '서울특별시 송파구 위례성대로 14', '서울특별시 양천구 목동남로 106', '서울특별시 성북구 삼선교로16길 118', '서울특별시 동대문구 장안벚꽃로 67', '서울특별시 종로구 인사동5길 26 홍익빌딩', '서울특별시 송파구 양산로 15', '서울특별시 중구 정동길 43', '서울특별시 종로구 지봉로5길 7-5', '서울특별시 은평구 증산로5길 6 (증산동 173-8) ', '서울특별시 양천구 목동동로 105', '서울특별시 양천구 지양로 47', '서울특별시 송파구 위례성대로 71', '서울특별시 노원구 노해로 437
# ...

# %%
import csv
count = 0
count_gu = 0
place = []
with open('datas/seoul_culture_place.csv','r')as f:
    data = csv.reader(f)
    header = next(data)
    place_gu = []
    # subject = {'기타','공연장','도서관'}
    # subject_list = []
    # subject_set = set()
    for row in data:         
        # subject_set.add(row[1])
        # place_gu.append(row[3])
        if row[1] == '기타':
           place.append(row[2]) 
           count += 1
        for i in subject_list:   
            if '강남' in row[3] and :
                gangnam_ += 1
            if '강동' in row[3] :
                gangdong += 1
            elif '강북' in row[3] :
                gangbuk += 1
            elif '강서' in row[3] :
                gangseo += 1
            elif '관악' in row[3] :
                gwanak += 1
            elif '광진' in row[3] :
                gwangjin += 1
            elif '구로' in row[3] :
                guro += 1
            elif '금천' in row[3] :
                geumcheon += 1
            elif '노원' in row[3] :
                nowon += 1
            elif '도봉' in row[3] :
                dobong += 1
            elif '동대문' in row[3] :
                dongdaemun += 1
            elif '동작' in row[3] :
                dongjak += 1
            elif '마포' in row[3] :
                mapo += 1
            elif '서대문' in row[3] :
                seodaemun += 1
            elif '서초' in row[3] :
                seocho += 1
            elif '성동' in row[3] :
                seongdong += 1
            elif '성북' in row[3] :
                seongbuk += 1
            elif '송파' in row[3] :
                songpa += 1
            elif '양천' in row[3] :
                yangcheon += 1
            elif '영등포' in row[3] :
                yeongdeungpo += 1
            elif '용산' in row[3] :
                yongsan += 1
            elif '은평' in row[3] :
                eunpyeong += 1
            elif '종로' in row[3] :
                jongno += 1
            elif '중구' in row[3] :
                jung += 1
            elif '중랑' in row[3] :
                jungnang += 1
print(dobong)        
print(nowon)
print(gangnam)
print(gangdong)
print(gangbuk)
print(gangseo)
print(gwanak)
print(gwangjin)
print(guro)
print(geumcheon)
print(nowon)
print(dobong)
print(dongdaemun)
print(dongjak)
print(mapo)
print(seodaemun)
print(seocho)
print(seongdong)
print(seongbuk)
print(songpa)
print(yangcheon)
print(yeongdeungpo)
print(yongsan)
print(eunpyeong)
print(jongno)
print(jung)
print(jungnang)
# print(count_gu)
# print(place_gu)
# print(place)
print(f'문화공간 셋 : {subject_set}')
subject_list = subject_set
print(f'문화공간 리스트 : {subject_list}')
# print(place[1])
# Out:
# 27
# 28
# 91
# 18
# 17
# 16
# 20
# 31
# 30
# 21
# 28
# 27
# 36
# 28
# 46
# 26
# 59
# 28
# 40
# 52
# 22
# 24
# 64
# 26
# 226
# 85
# 14
# 문화공간 셋 : {'문화예술회관', '문화원', '미술관', '공연장', '기타', '박물관/기념관', '도서관'}
# 문화공간 리스트 : {'문화예술회관', '문화원', '미술관', '공연장', '기타', '박물관/기념관', '도서관'}

# %%
for i in place:
    print(i)
# Out:
# 경희대학교
# DDP(동대문디자인플라자)
# 금천예술공장
# 양천구민체육센터
# 광진교 8번가
# 강북구청
# 구로구청
# 노들섬 복합문화공간
# 한성대학교
# 동대문구민체육센터
# 양천구청
# 노원구청
# 예지원
# 롯데월드 아이스링크
# 온조대왕문화체육관
# 용산구문화체육센터
# 올림픽기념국민생활관
# 육군사관학교
# 동대문구청
# 서울문화재단
# 시민청
# 동작구청
# 강남문화재단
# 서울풍물시장 전통문화체험관
# 강남스포츠문화센터
# 대진체육관
# 송파구청
# 서울문화예술교육센터 양천
# 중랑구평생학습관
# 국립국어원 우리말 꿈터
# 남산골한옥마을
# 구로구민체육센터
# 강남구민체육관
# 금천구청
# 누하동 259
# 해공체육문화센터
# 관악구민종합체육센터
# 강남구청
# 금빛휘트니스센터
# 북촌문화센터
# 강동구청
# 망원한강공원
# 녹사평 용산공원 플랫폼
# 내곡느티나무쉼터
# 이문체육문화센터
# 숭인근린공원
# 동대문구체육관
# 개운산스포츠센터
# 운현궁
# 중구청소년센터
# 중구여성플라자
# 영등포구청
# 중랑구민체육센터
# 강북웰빙스포츠센터
# 문화공간 이육사
# 서초여성가족플라자
# 세빛섬
# 문학의집서울
# SETEC전시장(서울무역전시장)
# 동대문구청 아트갤러리
# 평화문화진지
# 서울무용센터
# 등촌지역정보센터
# 잠실창작스튜디오
# 서교예술실험센터
# 성북문화재단
# 갈월종합사회복지관
# 은평구청소년문화의집 신나는애프터센터
# 중랑구민회관
# 서울특별시여성능력개발원
# 우리은행 본점
# 서울책보고
# 유담헌
# 성동문화재단
# 서울생각마루
# 사각사각 플레이스
# 이건하우스
# 서울자유시민대학
# 아트온더무브
# 구립용산장애인복지관
# 서울로 7017
# 관악청소년센터
# 현대카드 스토리지
# 서울과학기술대학교
# 장안평 자동차산업 종합정보센터
# 국립박물관문화재단
# 윤동주문학관
# 관악구청
# 호경재
# 세운협업지원센터
# 서울시창작공간
# 용산꿈나무종합타운
# 서울시립과학관
# 조계사
# 언더스탠드에비뉴
# 서울역사편찬원
# ...

# %%
def is_place_box_click():
    try:
        place_box_click = driver.find_element(By.CLASS_NAME, 'hfpxzc').click()
        time.sleep(2)
    except:
        try
            place_box_click = driver.find_element(By.xpath, '/html/body/div[1]/div[3]/div[8]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[1]/div[1]/div[1]/div/a').click()
            time.sleep(2)
        except:
            pass
def is_place_box_info(): 
    try:
        place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text
        time.sleep(1)
    except:
        try:
            place_box_name = driver.find_element(By.xpath, '/html/body/div[1]/div[3]/div[8]/div[9]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span[1]/span/button').text
            time.sleep(1)
        except:
            try:
                place_box_name = driver.find_element(By.CLASS_NAME, 'DUwDvf.lfPIob').text
                time.sleep(1)
            except:
                pass
# Out:
#   Cell In[5], line 6
#     try
#        ^
# SyntaxError: expected ':'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
value = []
# 크롬 드라이버 실행
driver = webdriver.Chrome()
count = 0
for i in range(3,278):
    # Google Maps 페이지 열기
    driver.get('https://www.google.com/maps/?authuser=0&entry=ttu&g_ep=EgoyMDI0MDgyMS4wIKXMDSoASAFQAw%3D%3D')
    
    # 페이지 로딩 대기
    time.sleep(3)
    
    # 검색창 요소 찾기
    search_box = driver.find_element(By.CLASS_NAME, 'searchboxinput')
    time.sleep(3)
    # 검색어 입력
    search_box.click()  # 검색창 클릭 (선택 사항)
    search_box.send_keys(place[i])
    # 검색 실행 (엔터 키 입력)
    search_box.send_keys(u'\ue007')  # 엔터 키를 의미하는 유니코드
    is_place_box_click
    is_place_box_info    
    time.sleep(3)
    #place_box_info = driver.find_element(By.xpath,'//*[@id="QA0Szd"]/div/div/div[1]/div[3]/div/div[1]/div/div/div[2]/div[2]/div/div[1]/div[2]/div/div[2]/span[1]/span/button')
    print(place_box_info)
    if place[i] == place_box_name:
        value.append(place_box_info)
    else:
        print(f'검색한 데이터가 {place[i]}가 아닙니다')
    time.sleep(3)
    count = count + 1
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[7], line 26
#      24 time.sleep(3)
#      25 try:
# ---> 26     place_box_click = driver.find_element(By.CLASS_NAME, 'hfpxzc').click()
#      27     time.sleep(3)
#      28 finally:
#
# File c:\Users\vvv\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\vvv\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
value = []
# 크롬 드라이버 실행
driver = webdriver.Chrome()
count = 0

# %%
# for i in range(278):
# Google Maps 페이지 열기
driver.get('https://www.google.com/maps/?authuser=0&entry=ttu&g_ep=EgoyMDI0MDgyMS4wIKXMDSoASAFQAw%3D%3D')

# 페이지 로딩 대기
time.sleep(3)

# %%
# for i in range(278):
# Google Maps 페이지 열기
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
value = []
# 크롬 드라이버 실행
driver = webdriver.Chrome()
count = 0
driver.get('https://www.google.com/maps/?authuser=0&entry=ttu&g_ep=EgoyMDI0MDgyMS4wIKXMDSoASAFQAw%3D%3D')

# 페이지 로딩 대기
time.sleep(3)
# 검색창 요소 찾기
search_box = driver.find_element(By.CLASS_NAME, 'searchboxinput')
time.sleep(3)
# 검색어 입력

search_box.click()  # 검색창 클릭 (선택 사항)
search_box.send_keys(place[6])

# 검색 실행 (엔터 키 입력)
search_box.send_keys(u'\ue007')  # 엔터 키를 의미하는 유니코드
time.sleep(3)

try:
    place_box_click = driver.find_element(By.CLASS_NAME, 'hfpxzc').click()
except:
    print('에러발생')
finally:
    time.sleep(3)

place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text

print(place_box_info)
value.append(place_box_info)
time.sleep(3)
count = count + 1
# Out:
# 학교

# %%
driver = webdriver.Chrome()
for i in range(278):
# Google Maps 페이지 열기
    driver.get('https://www.google.com/maps/?authuser=0&entry=ttu&g_ep=EgoyMDI0MDgyMS4wIKXMDSoASAFQAw%3D%3D')
    
    # 페이지 로딩 대기
    time.sleep(2)
    # 검색창 요소 찾기
    search_box = driver.find_element(By.CLASS_NAME, 'searchboxinput')
    time.sleep(1)
    # 검색어 입력
    
    search_box.click()  # 검색창 클릭 (선택 사항)
    search_box.send_keys(place[i])
    
    # 검색 실행 (엔터 키 입력)
    search_box.send_keys(u'\ue007')  # 엔터 키를 의미하는 유니코드
    time.sleep(1)
    
    try:
        place_box_click = driver.find_element(By.CLASS_NAME, 'hfpxzc').click()
    except:
        print('에러발생')
    finally:
        time.sleep(1)
    
    place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text

    print(place_box_info)
    value.append(place_box_info)
    time.sleep(1)
    count = count + 1
# Out:
# 사립대학교
# 카페
# 에러발생
# 아트 센터
# 에러발생
# 체육관
# 에러발생
# 문화적 랜드마크
# 숙박 업소
# 학교
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[200], line 27
#      24 finally:
#      25     time.sleep(1)
# ---> 27 place_box_info = driver.find_element(By.CLASS_NAME, 'DkEaL').text
#      29 print(place_box_info)
#      30 value.append(place_box_info)
#
# File C:\ana\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ana\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# ...

# %%
print(place[6])
# Out:
# 구로구청

# %%
print(place[1])
# Out:
# DDP(동대문디자인플라자)

# %%
# place_dic = dictionar
place_tuple = tuple(place)
# print(len(place))
# print(len(place_tuple))

# 딕셔너리 초기화
place_dic = {}

# 딕셔너리에 값 추가
for i in place:
    place_dic[i] = i

# 결과 출력
print(place_dic)
# Out:
# {'경희대학교': '경희대학교', 'DDP(동대문디자인플라자)': 'DDP(동대문디자인플라자)', '금천예술공장': '금천예술공장', '양천구민체육센터': '양천구민체육센터', '광진교 8번가': '광진교 8번가', '강북구청': '강북구청', '구로구청': '구로구청', '노들섬 복합문화공간': '노들섬 복합문화공간', '한성대학교': '한성대학교', '동대문구민체육센터': '동대문구민체육센터', '양천구청': '양천구청', '노원구청': '노원구청', '예지원': '예지원', '롯데월드 아이스링크': '롯데월드 아이스링크', '온조대왕문화체육관': '온조대왕문화체육관', '용산구문화체육센터': '용산구문화체육센터', '올림픽기념국민생활관': '올림픽기념국민생활관', '육군사관학교': '육군사관학교', '동대문구청': '동대문구청', '서울문화재단': '서울문화재단', '시민청': '시민청', '동작구청': '동작구청', '강남문화재단': '강남문화재단', '서울풍물시장 전통문화체험관': '서울풍물시장 전통문화체험관', '강남스포츠문화센터': '강남스포츠문화센터', '대진체육관': '대진체육관', '송파구청': '송파구청', '서울문화예술교육센터 양천': '서울문화예술교육센터 양천', '중랑구평생학습관': '중랑구평생학습관', '국립국어원 우리말 꿈터': '국립국어원 우리말 꿈터', '남산골한옥마을': '남산골한옥마을', '구로구민체육센터': '구로구민체육센터', '강남구민체육관': '강남구민체육관', '금천구청': '금천구청', '누하동 259': '누하동 259', '해공체육문화센터': '해공체육문화센터', '관악구민종합체육센터': '관악구민종합체육센터', '강남구청': '강남구청', '금빛휘트니스센터': '금빛휘트니스센터', '북촌문화센터': '북촌문화센터', '강동구청': '강동구청', '망원한강공원': '망원한강공원', '녹사평 용산공원 플랫폼': '녹사평 용산공원 플랫폼', '내곡느티나무쉼터': '내곡느티나무쉼터', '이문체육문화센터': '이문
# ...
